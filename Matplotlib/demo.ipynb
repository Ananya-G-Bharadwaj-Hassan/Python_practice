# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[4,5,6]

# %%
plt.plot(x,y) #1,4   2,5   3,6
plt.grid()
plt.show()

# %%
#Pyplot API
data={
    "salary":[25000,50000,40000,60000,30000,45000,20000,70000,65000]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#    salary
# 0   25000
# 1   50000
# 2   40000
# 3   60000
# 4   30000
# 5   45000
# 6   20000
# 7   70000
# 8   65000

# %%
#Line plot
plt.plot(df["salary"],color="orange",marker='o',linestyle='dashed',linewidth=2,markersize=10)
plt.show()

# %%
#Histogram
plt.hist(df["salary"],bins=5,color="green",edgecolor="black")
plt.show()

# %%
#Boxplot
plt.boxplot(df["salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b66b0f7250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b66b0f74d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b66b0f7110>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b66b0f7750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b66b0f7890>],
#  'means': []}

# %%
df["dept"]=["HR","IT","Finance","HR","HR","Sales","IT","Finance","Sales"]

# %%
#Pie chart
count=df["dept"].value_counts()
print(count)

plt.pie(count,labels=count.index,autopct="%1.1f",explode=[0,0.1,0.2,0])
# Out:
# dept
# HR         3
# IT         2
# Finance    2
# Sales      2
# Name: count, dtype: int64

# %%
#Count plot
plt.bar(count.index,count,color=["red","green","blue","yellow"])
# Out:
# <BarContainer object of 4 artists>
